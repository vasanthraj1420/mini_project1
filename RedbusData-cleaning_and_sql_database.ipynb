# %% [markdown]
# DATA CLEANING FOR SCRAPED DATA

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\vasan\Desktop\RED_BUS_PROJECT - Copy\df_bus_total-data.csv")
df
# Out:
#                     Route_name  \
# 0      Hyderabad to Vijayawada
# 1      Hyderabad to Vijayawada
# 2      Hyderabad to Vijayawada
# 3      Hyderabad to Vijayawada
# 4      Hyderabad to Vijayawada
# ...                        ...
# 12725         Kolkata to Digha
# 12726         Kolkata to Digha
# 12727         Kolkata to Digha
# 12728         Kolkata to Digha
# 12729         Kolkata to Digha
#
#                                               Route_link             Bus_name  \
# 0      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4972
# 1      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4894
# 2      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4898
# 3      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2573
# 4      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2678
# ...                                                  ...                  ...
# ...

# %%
df.describe()
# Out:
#                      Route_name  \
# count                     12730
# unique                      188
# top     Hyderabad to Vijayawada
# freq                        885
#
#                                                Route_link           Bus_name  \
# count                                               12730              12705
# unique                                                188               3937
# top     https://www.redbus.in/bus-tickets/hyderabad-to...  IntrCity SmartBus
# freq                                                  885                332
#
#                           Bus_type Departing_time Duration Reach_time  \
# count                        12705          12705    12705      12706
# unique                         161            595      571        672
# top     A/C Seater / Sleeper (2+1)          22:00  04h 00m      05:00
# freq                          1174            466      457        439
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                     Route_name  \
# 0      Hyderabad to Vijayawada
# 1      Hyderabad to Vijayawada
# 2      Hyderabad to Vijayawada
# 3      Hyderabad to Vijayawada
# 4      Hyderabad to Vijayawada
# ...                        ...
# 12725         Kolkata to Digha
# 12726         Kolkata to Digha
# 12727         Kolkata to Digha
# 12728         Kolkata to Digha
# 12729         Kolkata to Digha
#
#                                               Route_link             Bus_name  \
# 0      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4972
# 1      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4894
# 2      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4898
# 3      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2573
# 4      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2678
# ...                                                  ...                  ...
# ...

# %%
df.isnull().sum()
# Out:
# Route_name         0
# Route_link         0
# Bus_name          25
# Bus_type          25
# Departing_time    25
# Duration          25
# Reach_time        24
# Star_rating       24
# price             24
# Seat_available    24
# dtype: int64

# %%
df1=df.dropna(how='any')

# %%
df1
# Out:
#                     Route_name  \
# 0      Hyderabad to Vijayawada
# 1      Hyderabad to Vijayawada
# 2      Hyderabad to Vijayawada
# 3      Hyderabad to Vijayawada
# 4      Hyderabad to Vijayawada
# ...                        ...
# 12725         Kolkata to Digha
# 12726         Kolkata to Digha
# 12727         Kolkata to Digha
# 12728         Kolkata to Digha
# 12729         Kolkata to Digha
#
#                                               Route_link             Bus_name  \
# 0      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4972
# 1      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4894
# 2      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4898
# 3      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2573
# 4      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2678
# ...                                                  ...                  ...
# ...

# %%
df1.isnull().sum()
# Out:
# Route_name        0
# Route_link        0
# Bus_name          0
# Bus_type          0
# Departing_time    0
# Duration          0
# Reach_time        0
# Star_rating       0
# price             0
# Seat_available    0
# dtype: int64

# %%
df.shape
# Out:
# (12730, 10)

# %%
df2=df.dropna(how='all').shape
df2
# Out:
# (12447,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12730 entries, 0 to 12729
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Route_name      12730 non-null  object
#  1   Route_link      12730 non-null  object
#  2   Bus_name        12705 non-null  object
#  3   Bus_type        12705 non-null  object
#  4   Departing_time  12705 non-null  object
#  5   Duration        12705 non-null  object
#  6   Reach_time      12706 non-null  object
#  7   Star_rating     12706 non-null  object
#  8   price           12706 non-null  object
#  9   Seat_available  12706 non-null  object
# dtypes: object(10)
# memory usage: 994.7+ KB

# %%
df.isnull().sum()
# Out:
# Route_name         0
# Route_link         0
# Bus_name          25
# Bus_type          25
# Departing_time    25
# Duration          25
# Reach_time        24
# Star_rating       24
# price             24
# Seat_available    24
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Route_name        0
# Route_link        0
# Bus_name          0
# Bus_type          0
# Departing_time    0
# Duration          0
# Reach_time        0
# Star_rating       0
# price             0
# Seat_available    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12705 entries, 0 to 12729
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Route_name      12705 non-null  object
#  1   Route_link      12705 non-null  object
#  2   Bus_name        12705 non-null  object
#  3   Bus_type        12705 non-null  object
#  4   Departing_time  12705 non-null  object
#  5   Duration        12705 non-null  object
#  6   Reach_time      12705 non-null  object
#  7   Star_rating     12705 non-null  object
#  8   price           12705 non-null  object
#  9   Seat_available  12705 non-null  object
# dtypes: object(10)
# memory usage: 1.1+ MB

# %%
df1['price']
# Out:
# 0        INR 436
# 1        INR 436
# 2        INR 436
# 3        INR 670
# 4        INR 595
#           ...
# 12725    INR 250
# 12726    INR 220
# 12727    INR 300
# 12728    INR 249
# 12729    INR 220
# Name: price, Length: 12705, dtype: object

# %%
df1['price']=df1['price'].str.replace("INR","")
df1['price']=df1['price'].astype(float)
df1['price']
# Out:
# C:\Users\vasan\AppData\Local\Temp\ipykernel_16332\632643010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price']=df1['price'].str.replace("INR","")
# C:\Users\vasan\AppData\Local\Temp\ipykernel_16332\632643010.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price']=df1['price'].astype(float)
# 0        436.0
# 1        436.0
# 2        436.0
# 3        670.0
# 4        595.0
#          ...
# 12725    250.0
# 12726    220.0
# 12727    300.0
# 12728    249.0
# ...

# %%
df1
# Out:
#                     Route_name  \
# 0      Hyderabad to Vijayawada
# 1      Hyderabad to Vijayawada
# 2      Hyderabad to Vijayawada
# 3      Hyderabad to Vijayawada
# 4      Hyderabad to Vijayawada
# ...                        ...
# 12725         Kolkata to Digha
# 12726         Kolkata to Digha
# 12727         Kolkata to Digha
# 12728         Kolkata to Digha
# 12729         Kolkata to Digha
#
#                                               Route_link             Bus_name  \
# 0      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4972
# 1      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4894
# 2      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4898
# 3      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2573
# 4      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2678
# ...                                                  ...                  ...
# ...

# %%
df1['Star_rating']=df1['Star_rating'].str.replace("\n","")
df1['Star_rating']=df1['Star_rating'].apply(pd.to_numeric, errors='coerce')
df1['Star_rating']=df1['Star_rating'].round(1)
df1

# %%
df1['Seat_available']=df1['Seat_available'].str.replace("\n"," ")

# %%
df1
# Out:
#                     Route_name  \
# 0      Hyderabad to Vijayawada
# 1      Hyderabad to Vijayawada
# 2      Hyderabad to Vijayawada
# 3      Hyderabad to Vijayawada
# 4      Hyderabad to Vijayawada
# ...                        ...
# 12725         Kolkata to Digha
# 12726         Kolkata to Digha
# 12727         Kolkata to Digha
# 12728         Kolkata to Digha
# 12729         Kolkata to Digha
#
#                                               Route_link             Bus_name  \
# 0      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4972
# 1      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4894
# 2      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4898
# 3      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2573
# 4      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2678
# ...                                                  ...                  ...
# ...

# %%
df4=df1[df1["price"]<=7000]
df4
# Out:
#                     Route_name  \
# 0      Hyderabad to Vijayawada
# 1      Hyderabad to Vijayawada
# 2      Hyderabad to Vijayawada
# 3      Hyderabad to Vijayawada
# 4      Hyderabad to Vijayawada
# ...                        ...
# 12725         Kolkata to Digha
# 12726         Kolkata to Digha
# 12727         Kolkata to Digha
# 12728         Kolkata to Digha
# 12729         Kolkata to Digha
#
#                                               Route_link             Bus_name  \
# 0      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4972
# 1      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4894
# 2      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4898
# 3      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2573
# 4      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2678
# ...                                                  ...                  ...
# ...

# %%
df4['price'].max()
# Out:
# np.float64(6000.0)

# %%
df4.shape
# Out:
# (12704, 10)

# %%
df1.shape
# Out:
# (12705, 10)

# %%
path=(r"C:\Users\vasan\Desktop\data cleaning file\cleaning-data.csv")
df4.to_csv(path,index=False)

# %%
df4
# Out:
#                     Route_name  \
# 0      Hyderabad to Vijayawada
# 1      Hyderabad to Vijayawada
# 2      Hyderabad to Vijayawada
# 3      Hyderabad to Vijayawada
# 4      Hyderabad to Vijayawada
# ...                        ...
# 12725         Kolkata to Digha
# 12726         Kolkata to Digha
# 12727         Kolkata to Digha
# 12728         Kolkata to Digha
# 12729         Kolkata to Digha
#
#                                               Route_link             Bus_name  \
# 0      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4972
# 1      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4894
# 2      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 4898
# 3      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2573
# 4      https://www.redbus.in/bus-tickets/hyderabad-to...        APSRTC - 2678
# ...                                                  ...                  ...
# ...

# %% [markdown]
# CREATE MYSQL DATABASESE

# %%
import pandas as pd
import pymysql

# %%
conn=pymysql.connect(host="localhost",user="root",password="14201420vj")
my_cursor=conn.cursor()
my_cursor.execute("CREATE DATABASE IF NOT EXISTS  redbus_details ")
# Out:
# 1

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS bus_routedetails(
ID INT AUTO_INCREMENT PRIMARY KEY,
Route_name VARCHAR(300) NULL,
Route_link VARCHAR(300)NULL,
Bus_name VARCHAR(300)NOT NULL,
Bus_type VARCHAR(300)NOT NULL ,
Departing_time VARCHAR(300) NOT NULL,
Duration VARCHAR(300) NOT NULL,
Reach_time VARCHAR(300)NOT NULL,
Star_rating FLOAT NULL,
price FLOAT NULL,
Seat_available VARCHAR(300)NOT NULL
)''')
